# %%
import pandas as pd

# %%
df = pd.read_csv("datasets/covid_global.csv")

# %%
df.head()
# Out:
#   iso_code location        date  new_cases  aged_65_older  hosp_patients  \
# 0      BEL  Belgium  2021-08-09     4653.0         18.571          462.0
# 1      BEL  Belgium  2021-08-10     1748.0         18.571          465.0
# 2      BEL  Belgium  2021-08-11     2609.0         18.571          454.0
# 3      BEL  Belgium  2021-08-12     2119.0         18.571          475.0
# 4      BEL  Belgium  2021-08-13     2014.0         18.571          496.0
#
#    icu_patients  people_vaccinated  population  days  percentage_population  \
# 0         120.0          8251843.0  11632334.0     0               0.709388
# 1         120.0          8267925.0  11632334.0     1               0.710771
# 2         124.0          8284331.0  11632334.0     2               0.712181
# 3         132.0          8301389.0  11632334.0     3               0.713648
# 4         136.0          8315496.0  11632334.0     4               0.714860
#
#    weeks
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0

# %%
df_country = df[df.iso_code == "BEL"]

# %%
df_country
# Out:
#     iso_code location        date  new_cases  aged_65_older  hosp_patients  \
# 0        BEL  Belgium  2021-08-09     4653.0         18.571          462.0
# 1        BEL  Belgium  2021-08-10     1748.0         18.571          465.0
# 2        BEL  Belgium  2021-08-11     2609.0         18.571          454.0
# 3        BEL  Belgium  2021-08-12     2119.0         18.571          475.0
# 4        BEL  Belgium  2021-08-13     2014.0         18.571          496.0
# ..       ...      ...         ...        ...            ...            ...
# 96       BEL  Belgium  2021-11-13        0.0         18.571         1948.0
# 97       BEL  Belgium  2021-11-14        0.0         18.571         1948.0
# 98       BEL  Belgium  2021-11-15    27762.0         18.571         1948.0
# 99       BEL  Belgium  2021-11-16    12388.0         18.571         1948.0
# 100      BEL  Belgium  2021-11-17    18437.0         18.571         1948.0
#
# ...
